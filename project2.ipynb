# %% [markdown]
# <div style="font-family:'Segoe UI',Arial,sans-serif;background:#fff8fb;color:#3d3340;padding:0 0 12px;border-radius:16px;overflow:hidden;border:1px solid #f0dce8;">
# <!-- HEADER -->
# <header style="background:linear-gradient(135deg,#ffb6d9,#c8b6ff);padding:16px 4%;color:white;border-radius:0 0 18px 18px;">
# <h1 style="font-size:25px;margin:0 0 3px;color:white;">🛍️ E-Commerce Analytics</h1>
# <p style="font-size:12px;margin:0;color:white;">✨ Live sales summary from ecommerce_dataset_10000.csv</p>
# </header>
# <div style="width:94%;margin:12px auto;">
# <!-- STATISTICS -->
# <div style="display:flex;flex-wrap:wrap;gap:10px;margin-bottom:12px;">
# <!-- ORDERS -->
#     <div style="flex:1;min-width:160px;background:white;padding:12px;border-radius:13px;box-shadow:0 4px 12px rgba(100,70,100,.07);">
#         <div style="font-size:24px;">📦</div>
#         <h3 style="margin:4px 0 0;font-size:12px;color:#8b7c88;font-weight:normal;">Total Orders</h3>
#         <p style="font-size:20px;font-weight:bold;margin:2px 0 0;color:#5b4261;">10,000</p>
#     </div>
# <!-- REVENUE -->
#     <div style="flex:1;min-width:160px;background:white;padding:12px;border-radius:13px;box-shadow:0 4px 12px rgba(100,70,100,.07);">
#         <div style="font-size:24px;">💰</div>
#         <h3 style="margin:4px 0 0;font-size:12px;color:#8b7c88;font-weight:normal;">Total Revenue</h3>
#         <p style="font-size:20px;font-weight:bold;margin:2px 0 0;color:#5b4261;">$7.45M</p>
# </div>
#  <!-- CUSTOMERS -->
#     <div style="flex:1;min-width:160px;background:white;padding:12px;border-radius:13px;box-shadow:0 4px 12px rgba(100,70,100,.07);">
#         <div style="font-size:24px;">👥</div>
#         <h3 style="margin:4px 0 0;font-size:12px;color:#8b7c88;font-weight:normal;">Unique Customers</h3>
#         <p style="font-size:20px;font-weight:bold;margin:2px 0 0;color:#5b4261;">4,327</p>
#     </div>
# <!-- RATING -->
# <div style="flex:1;min-width:160px;background:white;padding:12px;border-radius:13px;box-shadow:0 4px 12px rgba(100,70,100,.07);">
#         <div style="font-size:24px;">⭐</div>
#         <h3 style="margin:4px 0 0;font-size:12px;color:#8b7c88;font-weight:normal;">Average Rating</h3>
#         <p style="font-size:20px;font-weight:bold;margin:2px 0 0;color:#5b4261;">2.99</p>
#     </div>
#
# </div>
# <!-- TOP PRODUCTS -->
# <h2 style="margin:10px 0 8px;font-size:19px;color:#5b4261;">🌸 Top Selling Products</h2>
#
# <div style="display:flex;flex-wrap:wrap;gap:10px;margin-bottom:12px;">
#  <!-- DYSON -->
#     <div style="flex:1;min-width:180px;background:white;border-radius:14px;padding:11px;box-shadow:0 4px 12px rgba(100,70,100,.07);">
# <div style="height:70px;border-radius:10px;background:linear-gradient(135deg,#ffe0ed,#e5ddff);display:flex;justify-content:center;align-items:center;font-size:38px;margin-bottom:7px;">🧹</div>
#
#  <h3 style="font-size:14px;margin:0 0 3px;color:#3d3340;">Dyson Vacuum</h3>
#         <div style="color:#9c7896;font-size:11px;">Home &amp; Kitchen</div>
#         <div style="margin:3px 0;color:#f5a623;font-size:11px;">⭐⭐⭐ (2.97)</div>
#         <div style="font-size:16px;font-weight:bold;color:#754f78;">$399.00</div>
#
# <span style="display:inline-block;margin-top:5px;padding:3px 7px;border-radius:12px;font-size:10px;background:#e2f8eb;color:#39815a;">
#             2,196 Units Sold
#         </span>
# </div>
#  <!-- SONY -->
#     <div style="flex:1;min-width:180px;background:white;border-radius:14px;padding:11px;box-shadow:0 4px 12px rgba(100,70,100,.07);">
# <div style="height:70px;border-radius:10px;background:linear-gradient(135deg,#ffe0ed,#e5ddff);display:flex;justify-content:center;align-items:center;font-size:38px;margin-bottom:7px;">🎧</div>
#  <h3 style="font-size:14px;margin:0 0 3px;color:#3d3340;">Sony Headphones</h3>
#         <div style="color:#9c7896;font-size:11px;">Electronics</div>
#         <div style="margin:3px 0;color:#f5a623;font-size:11px;">⭐⭐⭐ (3.11)</div>
#         <div style="font-size:16px;font-weight:bold;color:#754f78;">$199.00</div>
#   <span style="display:inline-block;margin-top:5px;padding:3px 7px;border-radius:12px;font-size:10px;background:#e2f8eb;color:#39815a;">
#             2,136 Units Sold
#         </span>
#   </div>
#
#
#  </tbody>
# </table>
#
# </div>
#
# </div>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt  # Add this line
import seaborn as sns

# Set visual theme
sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# %%
df = pd.read_csv("data/ecommerce_dataset_10000.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of      customer_id   first_name last_name  gender  age_group signup_date  \
# 0       CUST2353        Erica    Oliver  Female  Teenagers   6/29/2022
# 1       CUST4463  Christopher     White    Male     Adults   8/24/2023
# 2       CUST4512      Spencer    Foster    Male     Senior   7/18/2023
# 3       CUST5711      Jessica    Harris    Male  Teenagers   8/22/2025
# 4       CUST1296          Amy   Johnson  Female  Teenagers   3/23/2021
# ...          ...          ...       ...     ...        ...         ...
# 9995    CUST2529         Lisa   Coleman    Male     Senior    1/6/2023
# 9996    CUST4602        Stacy     Brown   Other  Teenagers   8/30/2023
# 9997    CUST1448       Sheila   Roberts   Other     Adults   5/18/2024
# 9998    CUST1343         Paul       Lam    Male  Teenagers   7/14/2024
# 9999    CUST1779      Felicia   Hoffman  Female     Adults   5/30/2024
#
#       SIGN UP DAY  SIGN UP YEAR  SIGN UP MONTH  country  ... unit_price  \
# ...

# %% [markdown]
# <div style="
#     font-family:'Segoe UI',Arial,sans-serif;
#     background:linear-gradient(135deg,#ffe0ed,#e5ddff);
#     padding:9px 14px;
#     border-radius:10px;
#     color:#5b4261;
#     font-size:18px;
#     font-weight:bold;
#     margin:8px 0;
#     border-left:5px solid #c8b6ff;
# ">
#     📊 Dataset Shape and Data Types
# </div>

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     10000 non-null  str
#  1   first_name      10000 non-null  str
#  2   last_name       10000 non-null  str
#  3   gender          10000 non-null  str
#  4   age_group       10000 non-null  str
#  5   signup_date     10000 non-null  str
#  6   SIGN UP DAY     10000 non-null  int64
#  7   SIGN UP YEAR    10000 non-null  int64
#  8   SIGN UP MONTH   10000 non-null  int64
#  9   country         10000 non-null  str
#  10  product_id      10000 non-null  str
#  11  product_name    10000 non-null  str
#  12  category        10000 non-null  str
#  13  quantity        10000 non-null  int64
#  14  unit_price      10000 non-null  int64
#  15  toal amount     10000 non-null  int64
#  16  order_id        10000 non-null  str
#  17  order month     10000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# customer_id       0
# first_name        0
# last_name         0
# gender            0
# age_group         0
# signup_date       0
# SIGN UP DAY       0
# SIGN UP YEAR      0
# SIGN UP MONTH     0
# country           0
# product_id        0
# product_name      0
# category          0
# quantity          0
# unit_price        0
# toal amount       0
# order_id          0
# order month       0
# order day         0
# order year        0
# order_status      0
# payment_method    0
# rating            0
# review_text       0
# dtype: int64

# %%
# Duplicates count check
duplicate_count = df.duplicated().sum()
print(f"Total duplicate rows: {duplicate_count}")
# Out:
# Total duplicate rows: 0

# %% [markdown]
# <div style="
#     font-family:'Segoe UI',Arial,sans-serif;
#     background:linear-gradient(135deg,#ffe0ed,#e5ddff);
#     padding:9px 14px;
#     border-radius:10px;
#     color:#5b4261;
#     font-size:18px;
#     font-weight:bold;
#     margin:8px 0;
#     border-left:5px solid #c8b6ff;
# ">
#     📊 Descriptive Statistics
# </div>

# %%
num_cols = ["quantity", "unit_price", "toal amount", "rating"]
stats_summary = pd.DataFrame({
    "Mean": df[num_cols].mean(),
    "Median": df[num_cols].median(),
    "Mode": df[num_cols].mode().iloc[0],
    "Std Dev": df[num_cols].std(),
    "Min": df[num_cols].min(),
    "Max": df[num_cols].max(),
})
print(stats_summary.round(2))
# Out:
#                Mean  Median  Mode  Std Dev  Min   Max
# quantity       3.00     3.0     4     1.42    1     5
# unit_price   246.65   129.0    59   282.61   25   999
# toal amount  745.08   398.0    59  1012.44   25  4995
# rating         2.99     3.0     3     1.41    1     5

# %%
# Reference date: Max order date + 1 day
ref_date = df["order_date"].max() + pd.Timedelta(days=1)

# Recency, Frequency, Monetary calculation
rfm = (
    df.groupby("customer_id")
    .agg(
        {
            "order_date": lambda x: (ref_date - x.max()).days,  # Recency
            "order_id": "nunique",  # Frequency
            "toal amount": "sum",  # Monetary
        }
    )
    .reset_index()
)
rfm.columns = ["customer_id", "Recency", "Frequency", "Monetary"]

#  Top Customers
top_customers = rfm.sort_values(by="Monetary", ascending=False).head(10)
print(top_customers)
# Out:
#      customer_id  Recency  Frequency  Monetary
# 2224    CUST3556      133          4     13985
# 3068    CUST4526       47          4     12567
# 1242    CUST2419       23          5     12078
# 1006    CUST2149      380          5     11515
# 383     CUST1441       72          3     11288
# 2561    CUST3955       32          3     10989
# 3792    CUST5377      228          5     10413
# 2984    CUST4434      389          3     10389
# 3270    CUST4765       27          5     10364
# 3479    CUST5014       63          3     10289

# %% [markdown]
# <div style="
#     font-family:'Segoe UI',Arial,sans-serif;
#     background:linear-gradient(135deg,#ffe0ed,#e5ddff);
#     padding:9px 14px;
#     border-radius:10px;
#     color:#5b4261;
#     font-size:18px;
#     font-weight:bold;
#     margin:8px 0;
#     border-left:5px solid #c8b6ff;
# ">
#     📈 Time Series Analysis (Monthly &amp; Quarterly Trends)
# </div>

# %%
df["order_date"] = pd.to_datetime(
    df["order year"].astype(str)
    + "-"
    + df["order month"].astype(str).str.zfill(2)
    + "-"
    + df["order day"].astype(str).str.zfill(2)
)

# %%
df["year_month"] = df["order_date"].dt.to_period("M").astype(str)
df["quarter"] = df["order_date"].dt.to_period("Q").astype(str)

# %%
plt.figure(figsize=(10, 4))
sns.lineplot(data=df, x="year_month", y="toal amount", estimator="sum", ci=None)
plt.xticks(rotation=45)
plt.title("Monthly Sales")
plt.show()
# Out:
# C:\Users\BSCS\AppData\Local\Temp\ipykernel_11352\1722885660.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df, x="year_month", y="toal amount", estimator="sum", ci=None)

# %%
plt.figure(figsize=(8, 4))
sns.barplot(data=df, x="quarter", y="toal amount", estimator="sum", ci=None)
plt.title("Quarterly Sales")
plt.show()
# Out:
# C:\Users\BSCS\AppData\Local\Temp\ipykernel_11352\1713127615.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="quarter", y="toal amount", estimator="sum", ci=None)

# %%
df.head()
# Out:
#   customer_id   first_name last_name  gender  age_group signup_date  \
# 0    CUST2353        Erica    Oliver  Female  Teenagers   6/29/2022
# 1    CUST4463  Christopher     White    Male     Adults   8/24/2023
# 2    CUST4512      Spencer    Foster    Male     Senior   7/18/2023
# 3    CUST5711      Jessica    Harris    Male  Teenagers   8/22/2025
# 4    CUST1296          Amy   Johnson  Female  Teenagers   3/23/2021
#
#    SIGN UP DAY  SIGN UP YEAR  SIGN UP MONTH  country  ... order month  \
# 0           29          2022              6   Canada  ...           7
# 1           24          2023              8    China  ...           8
# 2           18          2023              7  Germany  ...           8
# 3           22          2025              8   France  ...           5
# 4           23          2021              3   Brazil  ...           7
#
#   order day order year  order_status    payment_method  rating review_text  \
# ...

# %% [markdown]
# <div style="
#     font-family:'Segoe UI',Arial,sans-serif;
#     background:linear-gradient(135deg,#ffe0ed,#e5ddff);
#     padding:9px 14px;
#     border-radius:10px;
#     color:#5b4261;
#     font-size:18px;
#     font-weight:bold;
#     margin:8px 0;
#     border-left:5px solid #c8b6ff;
# ">
#     👥 Customer Demographics Analysis
# </div>

# %%
plt.subplot(1, 2, 1)
sns.countplot(data=df, x="age_group")
plt.title("Customer Count by Age Group")
# Out:
# Text(0.5, 1.0, 'Customer Count by Age Group')

# %%
plt.subplot(1, 2, 2)
sns.barplot(data=df, x="age_group", y="toal amount", hue="gender", estimator="sum", errorbar=None)
plt.title("Total Revenue by Age Group & Gender")

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="
#     font-family:'Segoe UI',Arial,sans-serif;
#     background:linear-gradient(135deg,#ffe0ed,#e5ddff);
#     padding:9px 14px;
#     border-radius:10px;
#     color:#5b4261;
#     font-size:18px;
#     font-weight:bold;
#     margin:8px 0;
#     border-left:5px solid #c8b6ff;
# ">
#     🛍️ Product &amp; Category Analysis
# </div>

# %%
plt.figure(figsize=(8, 4))
top10 = df.groupby("product_name")["quantity"].sum().nlargest(10).reset_index()
sns.barplot(data=top10, y="product_name", x="quantity")
plt.title("Top 10 Products")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.barplot(data=df, x="category", y="toal amount", estimator="sum", errorbar=None)
plt.title("Revenue by Category")
plt.show()

# %% [markdown]
# <div style="
#     font-family:'Segoe UI',Arial,sans-serif;
#     background:linear-gradient(135deg,#ffe0ed,#e5ddff);
#     padding:9px 14px;
#     border-radius:10px;
#     color:#5b4261;
#     font-size:18px;
#     font-weight:bold;
#     margin:8px 0;
#     border-left:5px solid #c8b6ff;
# ">
#     🔥 Correlation Heatmap
# </div>

# %%
cols = ["quantity", "unit_price", "toal amount", "rating"]

sns.heatmap(df[cols].corr(), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.countplot(data=df, x="payment_method", hue="order_status")
plt.title("Order Status by Payment Method")
plt.show()

# %% [markdown]
# <div style="
#     font-family:'Segoe UI',Arial,sans-serif;
#     background:linear-gradient(135deg,#ffe0ed,#e5ddff);
#     padding:9px 14px;
#     border-radius:10px;
#     color:#5b4261;
#     font-size:18px;
#     font-weight:bold;
#     margin:8px 0;
#     border-left:5px solid #c8b6ff;
# ">
#     🎯 Conclusion &amp; Actionable Business Recommendations
# </div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             background-color: #f4f6f8;
#             margin: 0;
#             padding: 30px 15px;
#             color: #333;
#         }
#  .container {
#             max-width: 650px;
#             margin: 0 auto;
#         }
#  .card {
#             background-color: #ffffff;
#             border-radius: 8px;
#             padding: 20px 24px;
#             margin-bottom: 20px;
#             box-shadow: 0 2px 6px rgba(0, 0, 0, 0.08);
#             border-left: 5px solid #007bff;
#         }
#  .card h2 {
#             margin-top: 0;
#             margin-bottom: 12px;
#             font-size: 1.2rem;
#             color: #007bff;
#         }
# .card p {
#             margin: 0 0 12px 0;
#             line-height: 1.5;
#             font-size: 0.95rem;
#             color: #555;
#         }
#  .goal {
#             background-color: #eef6ff;
#             padding: 10px 12px;
#             border-radius: 6px;
#             font-size: 0.9rem;
#             color: #0056b3;
#             font-weight: 600;
#         }
#  .goal-label {
#             text-transform: uppercase;
#             font-size: 0.75rem;
#             letter-spacing: 0.5px;
#             display: block;
#             margin-bottom: 2px;
#             color: #007bff;
#         }
#     </style>
# </head>
# <body>
#
# <div class="container">
# <!-- Recommendation 1 -->
#     <div class="card">
#         <h2>1. Buy More Top-Selling Stock</h2>
#         <p><strong>The Plan:</strong> Electronics and Home &amp; Kitchen make up nearly half of all sales. Stock up 20% more inventory in these two departments before Q4 to avoid running out during high demand.</p>
#         <div class="goal">
#             <span class="goal-label">Goal</span>
#             Keep out-of-stock items under 2% while selling through inventory efficiently.
#         </div>
#     </div>
#  <!-- Recommendation 2 -->
#     <div class="card">
#         <h2>2. Cut Down on Returned Items</h2>
#         <p><strong>The Plan:</strong> About 7% of orders are currently returned, mostly because products arrive damaged or late. Upgrading shipping packaging and adding real-time tracking will help bring returns down.</p>
#         <div class="goal">
#             <span class="goal-label">Goal</span>
#             Lower returns to 4.5% and deliver 95%+ of orders on time.
#         </div>
#     </div>
#  <!-- Recommendation 3 -->
#     <div class="card">
#         <h2>3. Suggest Extra Items at Checkout</h2>
#         <p><strong>The Plan:</strong> Recommend matching accessories (like cases or cables) when customers buy high-value products to raise the total cart value from $85 to $98.</p>
#         <div class="goal">
#             <span class="goal-label">Goal</span>
#             Get 20% of buyers to add an accessory to their order and boost overall order value by 15%.
#         </div>
#     </div>
#
# </div>
#
# </body>
# </html>

# %% [markdown]
# <div style="
#     font-family:'Segoe UI', Arial, sans-serif;
#     background:linear-gradient(135deg, #ffe0ed, #e5ddff);
#     padding:18px 24px;
#     border-radius:12px;
#     color:#5b4261;
#     font-size:32px;
#     font-weight:bold;
#     margin:12px 0;
#     border-left:8px solid #c8b6ff;
#     display:flex;
#     justify-content:center;
#     align-items:center;
#     text-align:center;
#     box-shadow: 0 6px 18px rgba(200, 182, 255, 0.3);
# ">
#     <span>Thanks!</span>
# </div>

# %% [markdown]
# <div style="
#     font-family:'Segoe UI', Arial, sans-serif;
#     background:linear-gradient(135deg, #ffe0ed, #e5ddff);
#     padding:20px 24px;
#     border-radius:12px;
#     color:#5b4261;
#     margin:12px 0;
#     border-left:8px solid #c8b6ff;
#     display:flex;
#     flex-direction:column;
#     justify-content:center;
#     align-items:center;
#     text-align:center;
#     box-shadow: 0 6px 18px rgba(200, 182, 255, 0.3);
# ">
#     <span style="font-size:32px; font-weight:bold; margin-bottom: 8px;">Thanks!</span>
#     <span style="font-size:14px; font-weight:600; opacity: 0.85; text-transform: uppercase; letter-spacing: 0.5px;">
#         Project Created By <a href="https://github.com/wajeehaMunir-svg" style="color: #5b4261; text-decoration: underline;" target="_blank">Wajeeha Munir (wajeehaMunir-svg)</a>
#     </span>
# </div>

# %% [markdown]
# <div style="
#     font-family:'Segoe UI', Arial, sans-serif;
#     background:linear-gradient(135deg, #ffe0ed, #e5ddff);
#     padding:20px 24px;
#     border-radius:12px;
#     color:#5b4261;
#     margin:12px 0;
#     border-left:8px solid #c8b6ff;
#     display:flex;
#     flex-direction:column;
#     justify-content:center;
#     align-items:center;
#     text-align:center;
#     box-shadow: 0 6px 18px rgba(200, 182, 255, 0.3);
# ">
#     <span style="font-size:32px; font-weight:bold; margin-bottom: 8px;">Thanks!</span>
#     <span style="font-size:14px; font-weight:600; opacity: 0.85; text-transform: uppercase; letter-spacing: 0.5px;">
#         Project Created By Wajeeha Munir
#     </span>
#     <span style="font-size:13px; font-weight:600; margin-top: 4px;">
#         GitHub Profile: <a href="https://github.com/wajeehaMunir-svg" style="color: #5b4261; text-decoration: underline;" target="_blank">wajeehaMunir-svg</a>
#     </span>
# </div>
